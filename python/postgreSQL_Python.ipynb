# %%
# !pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.8 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 8.2 MB/s eta 0:00:00
# ...

# %%
secret = 'your_password_here'

# %%
import psycopg2 as pg2

conn = pg2.connect(database='dvdrental', user='postgres', password='password', host='localhost', port='5432')

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM payment')

# %%
data = cur.fetchmany()

# %%
data[0][4]
# Out:
# Decimal('2.99')

# %%
conn.close()

# %%
add = 'DROP TABLE'
command = 'SELECCT * FROM' + add
cur.execute(command)

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'age', 'university', 'degree_level', 'degree_major', 'academic_year', 'cgpa', 'residential_status', 'campus_discrimination', 'sports_engagement', 'average_sleep', 'study_satisfaction', 'academic_workload ', 'academic_pressure', 'financial_concerns', 'social_relationships', 'depression', 'anxiety', 'isolation', 'future_insecurity', 'stress_relief_activities']

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("C:/Users/Destya Rosa/Downloads/MentalHealthSurvey.csv")

# 🔥 FIX COLUMN NAME
df.columns = df.columns.str.strip()

engine = create_engine("postgresql://postgres:password@localhost:5432/mentalhealth")

df.to_sql("mh_data", engine, if_exists="append", index=False)
# Out:
# 87
